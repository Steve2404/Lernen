# %% [markdown]
# <a href="https://colab.research.google.com/github/Steve2404/Lernen/blob/cagnotte/password.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import getpass

# %%
password = getpass.getpass("Entrez votre mot de passe: ")
